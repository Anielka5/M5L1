# %% [markdown]
# <a href="https://colab.research.google.com/github/Anielka5/M5L1/blob/main/Kopia_notatnika_m5l1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
def change_back(background, img):
    x, y = 0, 0
    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)
    res = np.copy(background)
    place = res[y: y + img.shape[0], x: x + img.shape[1]]
    a = img[..., 3:].repeat(3, axis=2).astype('uint16')
    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255

    return res

# %% [markdown]
# \

# %%
from google.colab.patches import cv2_imshow
import cv2
background = cv2.imread("/content/trawa.jpg")
img = cv2.imread("/content/output.png", cv2.IMREAD_UNCHANGED)

result = change_back(background, img)
cv2_imshow(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-661210801.py in <cell line: 0>()
#       4 img = cv2.imread("/content/output.png", cv2.IMREAD_UNCHANGED)
#       5
# ----> 6 result = change_back(background, img)
#       7 cv2_imshow(result)
#
# /tmp/ipython-input-2680065954.py in change_back(background, img)
#       3 def change_back(background, img):
#       4     x, y = 0, 0
# ----> 5     background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)
#       6     res = np.copy(background)
#       7     place = res[y: y + img.shape[0], x: x + img.shape[1]]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from rembg import remove

with open('imgage.png', 'rb') as i:
    with open('output.png', 'wb') as o:
        input = i.read()
        output = remove(input)
        o.write(output)

# %%
# !pip install rembg[cpu]
# !pip install rembg, numpy, cv2, oxnoroutime
from rembg import remove as remove
import numpy as np
import cv2 as image
from google.colab.patches import cv2_imshow as image_show
def remove_and_replace_background(background, url):
  with open(url, 'rb') as i:
    with open('output.png', 'wb') as o:
        input = i.read()
        output = remove(input)
        o.write(output)
  def change(img):
    x, y = 0, 0
    background = image.resize(background, (img.shape[1], img.shape[0]), interpolation = image.INTER_AREA)
    res = np.copy(background)
    place = res[y: y + img.shape[0], x: x + img.shape[1]]
    a = img[..., 3:].repeat(3, axis=2).astype('uint16')
    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255

    return res

  background = image.imread(background)
  img = image.imread("/content/output.png", image.IMREAD_UNCHANGED)

  result = change(background, img)
  image_show(result)
  image = image.imread(result)
  # The text string
  text = "Mem mojego autorstwa"
  # Czcionka
  font = image.FONT_HERSHEY_SIMPLEX
  # Rozmiar czcionki
  font_scale = 1
  # Kolor w formacie BGR (niebieski, zielony, czerwony).
  # To jest kolor biały
  color = (255, 255, 255)
  # Myślenie o linii
  thickness = 2
  image_with_text = cv2.putText(image, text, (x, y), font, font_scale, color, thickness, cv2.LINE_AA)
  image_show(image_with_text)
  image.imwrite(result, image_with_text)

# %%
remove_and_replace_background('trawa.jpg', 'kot.jpg')
